# %% [markdown]
# ## Model integration with google,groq and openai

# %%
import os
from dotenv import load_dotenv
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.5.3', 'langchain': '1.3.14', 'langchain-openai': '1.4.1'}}, output_version=None, profile={'name': 'GPT-4.1', 'release_date': '2025-04-14', 'last_updated': '2025-04-14', 'open_weights': False, 'max_input_tokens': 1047576, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x000001DD2F264590>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001DD2F265010>, root_client=<openai.OpenAI object at 0x000001DD2E84A510>, root_async_client=<openai.AsyncOpenAI object at 0x000001DD2F264D70>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0)

# %%
response = model.invoke("Hello how are you?")
response

# %% [markdown]
# ## GEMINI

# %%
model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")

response.content
# Out:
# 'Parrots talk due to a fascinating combination of unique biological features, high intelligence, and strong social instincts. Here\'s a breakdown of the main reasons:\n\n1.  **Vocal Learning Ability:** This is the most crucial factor. Unlike most animals that have a fixed set of innate vocalizations, parrots are **vocal learners**. This means they can acquire and reproduce new sounds throughout their lives, much like humans learn to speak different languages. Their brains have specialized "vocal learning centers" that allow them to process and imitate sounds.\n\n2.  **Unique Vocal Anatomy:** Parrots possess a highly flexible vocal organ called the **syrinx** (the avian equivalent of a larynx). This syrinx, combined with their thick, muscular tongue, gives them incredible control over the sounds they produce, allowing them to mimic a wide range of tones, pitches, and speech patterns.\n\n3.  **High Intelligence:** Parrots are among the most intelligent birds. They have sophisticated cognitive abilities, including problem-solving skills, memory, and the capacity for association. This intelligence allows them to:\n    *   **Associate sounds with meaning:** While they don\'t understand language in the same way humans do, they can learn to associate specific words or phrases with objects, actions, or contexts (e.g., saying "hello" when someone enters a room, or "want a cracker" to request a treat).\n    *   **Contextual learning:** They learn when and where certain sounds are appropriate.\n\n4.  **Social Nature and Desire to Belong:** Parrots are highly social animals that live in flocks in the wild.\n    *   **Flock Integration:** When a parrot lives with humans, it views its human companions as its "flock." To integrate and communicate with this "flock," the parrot attempts to mimic the dominant sounds of its environment – which, in a human home, is human speech.\n    *   **Attention and Bonding:** When a parrot talks, it often gets a positive reaction from its human caregivers (attention, praise, treats). This reinforces the behavior, making the parrot more likely to talk again. It\'s a powerful way for them to bond and get attention.\n\n5.  **Mimicry in the Wild:** Even in their natural habitats, parrots mimic sounds. They might imitate other bird species, predator calls, or environmental sounds. This ability likely serves various purposes, such as warning calls, identifying flock members, or even camouflage. When brought into a human environment, human speech simply becomes another set of sounds for them to mimic.\n\nIn essence, parrots talk because they have the biological hardware (syrinx, vocal learning brain centers), the cognitive capacity (intelligence, association), and the social drive (flock integration, attention) to do so. They are trying to communicate and fit in with their "flock," and human speech is the most prominent form of communication in their adopted environment.'

# %% [markdown]
# ### STREAMING :
# type as it generates

# %%
for chunk in model.stream("Write me 200 word para on ai"):
    print(chunk.text)
# Out:
# Artificial intelligence (AI) represents the simulation of human intelligence in machines programmed to think and learn
# . From the algorithms powering our social media feeds to the voice assistants in our homes, AI is no longer a futuristic concept but an integral part of our daily lives. It enables systems to perceive their environment, learn from data, reason, problem-solve,
#  and even create, often surpassing human capabilities in specific tasks.
#
# The transformative potential of AI is immense. In healthcare, it aids in diagnosing diseases earlier and developing personalized treatments. In scientific research, it accelerates discovery by analyzing vast datasets. Industries
#  leverage AI for automation, predictive maintenance, and optimizing supply chains, leading to unprecedented efficiencies and innovations. Beyond practical applications, AI is pushing the boundaries of creativity, generating art, music, and literature.
#
# However, the rapid evolution of AI
#  also brings significant considerations. Ethical concerns around data privacy, bias in algorithms, job displacement, and the need for responsible development are paramount. As AI continues to advance, it promises to reshape nearly every aspect of human existence, offering solutions to complex
#  global challenges while demanding careful navigation of its societal impact. Its journey is just beginning, poised to redefine what's possible.

# %% [markdown]
# ### BATCH:

# %%
responses = model.batch([
    "Why do parrots fly?",
    "Why is leap year",
    "WhAT IS agentic ai"
])

for response in responses:
    print(response)
# Out:
# content="Parrots fly for a multitude of essential reasons, all critical for their survival, reproduction, and overall well-being in their natural habitats:\n\n1.  **To Find and Access Food:** Parrots primarily eat fruits, nuts, seeds, flowers, and nectar, which are often found high in trees or scattered across large areas. Flight allows them to efficiently forage, moving from one food source to another and accessing parts of trees that ground-bound animals cannot reach.\n\n2.  **To Escape Predators:** As prey animals, flight is their primary defense mechanism. It allows them to quickly escape from predators such as raptors (eagles, hawks), snakes, monkeys, and other arboreal or terrestrial hunters.\n\n3.  **To Navigate Their Habitat:** Parrots live in complex environments like forests, jungles, and woodlands. Flight enables them to navigate dense foliage, move between trees, cross open spaces, and efficiently traverse their home range to find necessary resources.\n\n4.  **To Find Suitable Nesting and Roosting Sites:** Parrots typically nest in tree hollows. Flight allows them to locate and access these high, safe cavities, as well as finding secure roosting locations where they can sleep safely away from ground predators.\n\n5.  **For Social Interaction and Reproduction:** Parrots are highly social birds, often flying in flocks. Flight facilitates flock movements, allows them to find mates, participate in courtship displays (some species perform aerial acrobatics), and maintain social cohesion.\n\n6.  **To Access Water Sources:** Just like food, water sources may be spread out. Flight allows parrots to travel to rivers, streams, and other water bodies when needed.\n\n7.  **To Adapt to Seasonal Changes:** While many parrots don't undertake long-distance migrations like some other bird species, some may make local or regional movements to follow food availability or escape unfavorable seasonal conditions.\n\nIn essence, flight is not just a capability for parrots; it's a cornerstone of their survival, foraging, social structure, and reproduction in their natural habitats." additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019fcc6c-b3a0-7d01-9cb0-10c793d1c0d8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 1339, 'total_tokens': 1345, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 920}}
# content='A leap year is necessary to keep our calendar year synchronized with the astronomical year, which is the actual time it takes for the Earth to orbit the Sun.\n\nHere\'s a breakdown of why:\n\n1.  **The Mismatch:**\n    *   Our standard calendar year has **365 days**.\n    *   The actual time it takes for the Earth to complete one full orbit around the Sun (a "tropical year" or "solar year") is approximately **365 days, 5 hours, 48 minutes, and 45 seconds**.\n    *   This "extra" nearly 6 hours doesn\'t fit neatly into our 365-day calendar.\n\n2.  **The Problem if We Didn\'t Have Leap Years:**\n    *   If we simply ignored those extra ~6 hours each year, our calendar would gradually drift out of sync with the seasons.\n    *   After 4 years, we would have accumulated almost an entire extra day (6 hours x 4 years = 24 hours).\n    *   Over time, this drift would become significant. For example, if we didn\'t have leap years, eventually Christmas would occur in the middle of summer in the Northern Hemisphere, and seasons for planting and harvesting would no longer align with the calendar dates.\n\n3.  **The Solution: The Leap Day:**\n    *   To correct this drift, we add an extra day, **February 29th**, to the calendar approximately every four years.\n    *   This "leap day" accounts for the accumulated ~6 hours, effectively resetting the calendar\'s alignment with the Earth\'s position in its orbit.\n\n4.  **The Refinement (Gregorian Calendar Rules):**\n    *   Adding a full day every four years (which averages to 365.25 days per year) is actually a slight overcorrection, because the solar year is slightly *less* than 365.25 days (it\'s about 365.2425 days).\n    *   To correct for this overcorrection, the Gregorian calendar (the one most of the world uses) has these additional rules:\n        *   A year is a leap year if it is **divisible by 4**.\n        *   **Except** if it is divisible by **100** (e.g., 1900, 2100 are NOT leap years).\n        *   **Unless** it is also divisible by **400** (e.g., 2000 WAS a leap year).\n\nIn essence, leap years are a clever calendrical adjustment to ensure that our human-made calendar stays in step with the natural rhythms of the Earth\'s journey around the Sun, keeping seasons and astronomical events consistent with their dates.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019fcc6c-b3ac-79f2-bb31-5d52a75d4234-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 1532, 'total_tokens': 1537, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 935}}
# content='**Agentic AI** refers to an artificial intelligence system that can take initiative, plan, and execute a series of actions autonomously to achieve a specific, often complex, goal.\n\nUnlike a traditional AI model that simply responds to a single query (like a chatbot answering a question), an agentic AI is designed to break down a high-level objective into smaller sub-tasks, determine the best course of action, use various tools or APIs, monitor its progress, and adapt its plan as needed until the goal is accomplished.\n\nThink of it less like a calculator that gives you an answer to a single problem, and more like a personal assistant that you give a broad objective to, and it then figures out all the steps to get it done.\n\nHere\'s a breakdown of its key characteristics:\n\n1.  **Goal-Oriented:** It operates with a defined objective in mind, rather than just waiting for a prompt.\n2.  **Autonomy & Initiative:** It can make decisions and take actions without constant human intervention. It initiates steps to move towards its goal.\n3.  **Planning & Reasoning:** It can formulate a plan to achieve its goal, often breaking down complex tasks into manageable sub-tasks. It can reason about the best sequence of actions.\n4.  **Execution & Tool Use:** It can interact with the digital world (and potentially the physical world) by using various tools, APIs, web browsers, databases, or even other AI models to perform actions.\n5.  **Monitoring & Self-Correction:** It can observe the results of its actions, evaluate its progress, and adjust its plan or strategy if an action fails or if new information becomes available.\n6.  **Memory & Context:** It maintains a working memory of its past actions, observations, and the overall context of its mission, allowing it to learn and make more informed decisions over time.\n\n**How it Works (Simplified Process):**\n\n1.  **Goal Input:** A human provides a high-level goal (e.g., "Research the best marketing strategies for a new SaaS product.").\n2.  **Goal Decomposition:** The agentic AI, often powered by a large language model (LLM) as its "brain," breaks down this goal into smaller, actionable sub-tasks (e.g., "Identify key competitors," "Analyze their marketing channels," "Research industry best practices," "Synthesize findings into a report").\n3.  **Planning:** It creates a plan of action, determining the order of tasks and what tools might be needed for each.\n4.  **Execution:** It starts executing the plan. For example, it might use a web browsing tool to search for competitors, then an API to gather data, then a text generation tool to draft parts of the report.\n5.  **Observation & Reflection:** After each action, it observes the outcome. Did it get the information it needed? Was the action successful?\n6.  **Iteration & Refinement:** Based on its observations, it reflects on its progress. If a step failed, it might try a different approach. If it gathered new information, it might refine its plan.\n7.  **Goal Achievement:** It continues this cycle until the overall goal is met, or it determines it cannot proceed further and reports back to the human.\n\n**Why is Agentic AI Significant?**\n\nAgentic AI represents a significant leap from reactive AI systems to proactive ones. It allows for the automation of more complex, multi-step tasks that traditionally required human oversight and decision-making, opening up possibilities for more powerful personal assistants, autonomous research systems, automated software development, and much more.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019fcc6c-b3ad-7013-a618-603f501966de-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 1901, 'total_tokens': 1908, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1148}}
